# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/fire_safety/blob/master/%ED%99%94%EC%9E%AC%EA%B3%B5%EB%AA%A8%EC%A0%84_1011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 파일 불러오기

import pandas as pd
df= pd.read_csv('water_accident.csv')
df.head()
# Out:
#   msfrtn_resc_reprt_no acdnt_cause prcs_result_se_nm  dclr_ymd  dclr_tm  \
# 0    20114506102S00001          수난              안전조치  20110101   222600
# 1    20114506305S00001          수난              인명구조  20110101   222600
# 2    20114503601S00001          수난              인명구조  20110104   194900
# 3    20114504105S00006          수난              인명구조  20110118   141200
# 4    20114509201S00030          수난              인명구조  20110120   121800
#
#    dclr_yr season_se_nm  qu_se  dclr_mnth  dclr_day  ...  \
# 0     2011           겨울      1          1         1  ...
# 1     2011           겨울      1          1         1  ...
# 2     2011           겨울      1          1         4  ...
# 3     2011           겨울      1          1        18  ...
# 4     2011           겨울      1          1        20  ...
#
#    acdnt_cause_asort_nm  time_unit_tmprt time_unit_rainqty  time_unit_ws  \
# 0                  수난기타              NaN               NaN           NaN
# ...

# %%
# 데이터의 열 확인

print(df.columns)
# Out:
# Index(['msfrtn_resc_reprt_no', 'acdnt_cause', 'prcs_result_se_nm', 'dclr_ymd',
#        'dclr_tm', 'dclr_yr', 'season_se_nm', 'qu_se', 'dclr_mnth', 'dclr_day',
#        'dclr_hour', 'dclr_min', 'daywk', 'dsp_ymd', 'dsp_tm', 'dsp_yr',
#        'dsp_mnth', 'dsp_day', 'dsp_hour', 'dsp_min', 'spt_arvl_ymd',
#        'spt_arvl_tm', 'spt_arvl_yr', 'spt_arvl_mnth', 'spt_arvl_day',
#        'spt_arvl_hour', 'spt_arvl_min', 'resc_cmptn_ymd', 'resc_cmptn_tm',
#        'resc_cmptn_yr', 'resc_cmptn_mnth', 'resc_cmptn_day', 'resc_cmptn_hour',
#        'resc_cmptn_min', 'hmg_ymd', 'hmg_tm', 'hmg_yr', 'hmg_mnth', 'hmg_day',
#        'hmg_hour', 'hmg_min', 'sido_nm', 'sigungu_nm', 'emd_nm',
#        'cty_frmvl_se_nm', 'emd_se_nm', 'loc_info_x', 'loc_info_y',
#        'spt_frstt_dist', 'acdnt_place_nm', 'acdnt_place_detail_nm',
#        'acdnt_cause_asort_nm', 'time_unit_tmprt', 'time_unit_rainqty',
#        'time_unit_ws', 'time_unit_wd', 'time_unit_humidity', 'time_unit_msnf',
# ...

# %%
# 필요하지 않은 열 모두 삭제 후 df_new라는 새로운 데이터프레임 생성

df_new = df.drop(['msfrtn_resc_reprt_no','acdnt_cause','dclr_ymd','dclr_tm','qu_se','dclr_day','dclr_min','dsp_ymd','dsp_tm','dsp_yr','dsp_mnth',
                  'dsp_day','dsp_hour','dsp_min','spt_arvl_ymd','spt_arvl_tm','spt_arvl_yr','spt_arvl_mnth','spt_arvl_day','spt_arvl_hour','spt_arvl_min',
                  'resc_cmptn_ymd','resc_cmptn_tm','resc_cmptn_yr','resc_cmptn_mnth','resc_cmptn_day','resc_cmptn_hour','resc_cmptn_min',
                  'hmg_ymd','hmg_tm','hmg_yr','hmg_mnth','hmg_day','hmg_hour','hmg_min','emd_nm',
                  'emd_se_nm','loc_info_x','loc_info_y','spt_frstt_dist','acdnt_place_nm','time_unit_tmprt','time_unit_ws','time_unit_wd','time_unit_humidity','time_unit_msnf',
                  'frstt_nm','ward_nm','lfdau_nm'], axis=1)

# %%
df_new.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0              안전조치     2011           겨울          1         22   토요일    전라북도
# 1              인명구조     2011           겨울          1         22   토요일    전라북도
# 2              인명구조     2011           겨울          1         19   화요일    전라북도
# 3              인명구조     2011           겨울          1         14   화요일    전라북도
# 4              인명구조     2011           겨울          1         12   목요일    전라북도
#
#   sigungu_nm cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm  \
# 0       순창군               농촌                   저수지                 수난기타
# 1       순창군               농촌                    기타                   익수
# 2        군산시              도시                   저수지                 자살기도
# 3        익산시              도시                    하천                  물놀이
# 4       부안군               농촌                   강바다                 수난기타
#
#    time_unit_rainqty
# 0                NaN
# ...

# %%
# car_fire_new라는 이름으로 새롭게 csv 생성

df_new.to_csv('water_accident_new.csv', index=False)

# %%
# car_fire_new 데이터로 분석 시작

# %%
# 파일 불러오기

import pandas as pd
df= pd.read_csv('water_accident_new.csv')
df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0              안전조치     2011           겨울          1         22   토요일    전라북도
# 1              인명구조     2011           겨울          1         22   토요일    전라북도
# 2              인명구조     2011           겨울          1         19   화요일    전라북도
# 3              인명구조     2011           겨울          1         14   화요일    전라북도
# 4              인명구조     2011           겨울          1         12   목요일    전라북도
#
#   sigungu_nm cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm  \
# 0       순창군               농촌                   저수지                 수난기타
# 1       순창군               농촌                    기타                   익수
# 2        군산시              도시                   저수지                 자살기도
# 3        익산시              도시                    하천                  물놀이
# 4       부안군               농촌                   강바다                 수난기타
#
#    time_unit_rainqty
# 0                NaN
# ...

# %%
df = df.drop(['sigungu_nm','time_unit_rainqty'], axis=1)
df
# Out:
#      prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk  \
# 0                 안전조치     2011           겨울          1         22   토요일
# 1                 인명구조     2011           겨울          1         22   토요일
# 2                 인명구조     2011           겨울          1         19   화요일
# 3                 인명구조     2011           겨울          1         14   화요일
# 4                 인명구조     2011           겨울          1         12   목요일
# ...                ...      ...          ...        ...        ...   ...
# 2645              인명구조     2020           겨울         12         14   토요일
# 2646              안전조치     2020           겨울         12         14   토요일
# 2647              인명구조     2020           겨울         12          7   화요일
# 2648              인명구조     2020           겨울         12          7   화요일
# 2649              인명검색     2020           겨울         12         13   수요일
#
#      sido_nm cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm
# ...

# %%
# prcs_result_se_nm열 영어로 변경하기

# prcs_result_se_nm 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
translation_dict = {
    '인명구조': 'Rescue',
    '안전조치': 'Action',
    '인명검색': 'Search',
    '기타': 'Others'
}

# map 함수를 사용하여 prcs_result_se_nm 열의 값을 영어로 변환
df['prcs_result_se_nm'] = df['prcs_result_se_nm'].map(translation_dict)

df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0            Action     2011           겨울          1         22   토요일    전라북도
# 1            Rescue     2011           겨울          1         22   토요일    전라북도
# 2            Rescue     2011           겨울          1         19   화요일    전라북도
# 3            Rescue     2011           겨울          1         14   화요일    전라북도
# 4            Rescue     2011           겨울          1         12   목요일    전라북도
#
#   cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm
# 0              농촌                   저수지                 수난기타
# 1              농촌                    기타                   익수
# 2              도시                   저수지                 자살기도
# 3              도시                    하천                  물놀이
# 4              농촌                   강바다                 수난기타

# %%
# season_se_nm 영어로 변경하기

# season_se_nm 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
translation_dict_s = {
    '봄': 'Spring',
    '여름': 'Summer',
    '가을': 'Fall',
    '겨울': 'Winter'
}

# map 함수를 사용하여 season_se_nm 열의 값을 영어로 변환
df['season_se_nm'] = df['season_se_nm'].map(translation_dict_s)

df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0            Action     2011       Winter          1         22   토요일    전라북도
# 1            Rescue     2011       Winter          1         22   토요일    전라북도
# 2            Rescue     2011       Winter          1         19   화요일    전라북도
# 3            Rescue     2011       Winter          1         14   화요일    전라북도
# 4            Rescue     2011       Winter          1         12   목요일    전라북도
#
#   cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm
# 0              농촌                   저수지                 수난기타
# 1              농촌                    기타                   익수
# 2              도시                   저수지                 자살기도
# 3              도시                    하천                  물놀이
# 4              농촌                   강바다                 수난기타

# %%
# daywk 영어로 변경하기

# daywk 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
translation_dict_d = {
    '월요일': 'Mon',
    '화요일': 'Tue',
    '수요일': 'Wed',
    '목요일': 'Thu',
    '금요일': 'Fri',
    '토요일': 'Sat',
    '일요일': 'Sun'
}

# map 함수를 사용하여 daywk 열의 값을 영어로 변환
df['daywk'] = df['daywk'].map(translation_dict_d)

df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0            Action     2011       Winter          1         22   Sat    전라북도
# 1            Rescue     2011       Winter          1         22   Sat    전라북도
# 2            Rescue     2011       Winter          1         19   Tue    전라북도
# 3            Rescue     2011       Winter          1         14   Tue    전라북도
# 4            Rescue     2011       Winter          1         12   Thu    전라북도
#
#   cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm
# 0              농촌                   저수지                 수난기타
# 1              농촌                    기타                   익수
# 2              도시                   저수지                 자살기도
# 3              도시                    하천                  물놀이
# 4              농촌                   강바다                 수난기타

# %%
# cty_frmvl_se_nm 영어로 변경하기

# cty_frmvl_se_nm 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
translation_dict_ct = {
    '농촌': 'Rural',
    '도시': 'City'
}

# map 함수를 사용하여 season_se_nm 열의 값을 영어로 변환
df['cty_frmvl_se_nm'] = df['cty_frmvl_se_nm'].map(translation_dict_ct)

df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0            Action     2011       Winter          1         22   Sat    전라북도
# 1            Rescue     2011       Winter          1         22   Sat    전라북도
# 2            Rescue     2011       Winter          1         19   Tue    전라북도
# 3            Rescue     2011       Winter          1         14   Tue    전라북도
# 4            Rescue     2011       Winter          1         12   Thu    전라북도
#
#   cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm
# 0           Rural                   저수지                 수난기타
# 1           Rural                    기타                   익수
# 2            City                   저수지                 자살기도
# 3            City                    하천                  물놀이
# 4           Rural                   강바다                 수난기타

# %%
# # sido_nm 영어로 변경하기

# # sido_nm 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
# translation_dict_sd = {
#     '경상남도': 'GN',
#     '전라남도': 'JN',
#     '전라북도': 'JB'
# }

# # map 함수를 사용하여 sido_nm 열의 값을 영어로 변환
# df['sido_nm'] = df['sido_nm'].map(translation_dict_sd)

# df.head()

# %%
# # sigungu_nm 영어로 변경하기

# # sigungu_nm 열의 한글을 영어로 바꾸기 위한 딕셔너리 생성
# translation_dict_sd = {
#     '고창군': 'Gochang',
#     '군산시': 'Goonsan',
#     '김제시': 'Kimjae',
#     '남원시': 'Namwon',
#     '무주군': 'Mooju',
#     '부안군': 'Buan',
#     '순창군': 'Soonchang',
#     '완주군': 'Wanju',
#     '익산시': 'Iksan',
#     '임실군': 'Imsil',
#     '장수군': 'Jangsu',
#     '전주시덕진구': 'Junjudukjin',
#     '전주시완산구': 'Junjuwansan',
#     '정읍시': 'Jungeup',
#     '진도군': 'Jindo',
#     '진안군': 'Jinan',
#     '함양군': 'Hamyang'

# }

# # map 함수를 사용하여 sigungu_nm 열의 값을 영어로 변환
# df['sigungu_nm'] = df['sigungu_nm'].map(translation_dict_sd)

# df.head()
# Out:
#   prcs_result_se_nm  dclr_yr season_se_nm  dclr_mnth  dclr_hour daywk sido_nm  \
# 0            Action     2011       Winter          1         22   Sat      JB
# 1            Rescue     2011       Winter          1         22   Sat      JB
# 2            Rescue     2011       Winter          1         19   Tue      JB
# 3            Rescue     2011       Winter          1         14   Tue      JB
# 4            Rescue     2011       Winter          1         12   Thu      JB
#
#   sigungu_nm cty_frmvl_se_nm acdnt_place_detail_nm acdnt_cause_asort_nm  \
# 0        NaN              농촌                   저수지                 수난기타
# 1        NaN              농촌                    기타                   익수
# 2    Goonsan              도시                   저수지                 자살기도
# 3      Iksan              도시                    하천                  물놀이
# 4        NaN              농촌                   강바다                 수난기타
#
#    time_unit_rainqty
# 0                0.0
# ...

# %%
# 연도별 사고수

import matplotlib.pyplot as plt

# 'dclr_yr' 열을 기준으로 그룹화하고 각 그룹의 개수를 계산
year_counts = df.groupby('dclr_yr')['dclr_yr'].count()

# 막대 그래프를 생성
plt.bar(year_counts.index, year_counts.values)

# 그래프 제목과 축 레이블을 설정
plt.title('Number of Accidents by Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')

# 그래프 표시
plt.show()

# %%
# 계절별 사고 수

# 'season_se_nm' 열을 기준으로 그룹화하고 각 그룹의 개수를 계산
season_counts = df.groupby('season_se_nm')['season_se_nm'].count()


plt.rcParams['axes.unicode_minus'] =False

# 막대 그래프를 생성
plt.bar(season_counts.index, season_counts.values)

# 그래프 제목과 축 레이블을 설정
plt.title('Number of Accidents by Season')
plt.xlabel('Season')
plt.ylabel('Number of Accidents')

# 그래프 표시
plt.show()

# %%
# 요일별 사고 수

# 요일 순서 정의
day_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# 'daywk' 열을 범주형으로 변환하고 순서 지정
df['daywk'] = pd.Categorical(df['daywk'], categories=day_order, ordered=True)

# 'daywk' 열을 기준으로 그룹화하고 각 그룹의 개수를 계산
daywk_counts = df['daywk'].value_counts().reindex(day_order)


plt.rcParams['axes.unicode_minus'] =False

# 막대 그래프를 생성
plt.bar(daywk_counts.index, daywk_counts.values)

# 그래프 제목과 축 레이블을 설정
plt.title('Number of Accidents by Day of the Week')
plt.xlabel('Day of the week')
plt.ylabel('Number of Accidents')

# 그래프 표시
plt.show()

# %%
# 도시/농촌별 사고 수

# 'cty_frmvl_se_nm' 열을 기준으로 그룹화하고 각 그룹의 개수를 계산
cty_counts = df.groupby('cty_frmvl_se_nm')['cty_frmvl_se_nm'].count()


plt.rcParams['axes.unicode_minus'] =False

# 막대 그래프를 생성
plt.bar(cty_counts.index, cty_counts.values)

# 그래프 제목과 축 레이블을 설정
plt.title('Number of Accidents by Season')
plt.xlabel('city or Rural')
plt.ylabel('Number of Accidents')

# 그래프 표시
plt.show()

# %%
# 가장 사고가 많이 나는 곳 10개

place_detail_nm_10 = df['acdnt_place_detail_nm'].value_counts().head(10)
print(place_detail_nm_10)
# Out:
# acdnt_place_detail_nm
# 저수지         502
# 하천          384
# 하천,바다 기타    349
# 바다          272
# 강바다         228
# 지방(소)하천     189
# 기타 하천,바다    172
# 기타          139
# 강           119
# 국가하천(강)      36
# Name: count, dtype: int64
