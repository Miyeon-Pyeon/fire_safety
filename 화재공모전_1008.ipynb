# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/fire_safety/blob/master/%ED%99%94%EC%9E%AC%EA%B3%B5%EB%AA%A8%EC%A0%84_1008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 파일 불러오기

import pandas as pd
df= pd.read_csv('car_fire_2023.csv')
df.head()
# Out:
#        wrinvstg_no fire_type_nm  dth_cnt  injpsn_cnt  dth_hnl_dmge_cnt  \
# 0  230101203108519     자동차/철도차량        0           0                 0
# 1  230104013930741     자동차/철도차량        0           0                 0
# 2  230105164039514     자동차/철도차량        0           0                 0
# 3  230106110105480     자동차/철도차량        0           0                 0
# 4  230106123133123     자동차/철도차량        0           0                 0
#
#    prprty_dmge_amt  fire_ocrn_yr season_se_nm  qtr_se  fire_ocrn_ymd  ...  \
# 0               50          2023           겨울       1       20230101  ...
# 1              924          2023           겨울       1       20230104  ...
# 2               66          2023           겨울       1       20230105  ...
# 3            10271          2023           겨울       1       20230106  ...
# 4              160          2023           겨울       1       20230106  ...
#
#    vhcle_place  vhcle_ign_bhf  emrg_crg_oper_yn  time_unit_tmprt  \
# ...

# %%
# 데이터의 열 확인

print(df.columns)
# Out:
# Index(['wrinvstg_no', 'fire_type_nm', 'dth_cnt', 'injpsn_cnt',
#        'dth_hnl_dmge_cnt', 'prprty_dmge_amt', 'fire_ocrn_yr', 'season_se_nm',
#        'qtr_se', 'fire_ocrn_ymd', 'fire_ocrn_tm', 'fire_ocrn_mnth',
#        'fire_ocrn_day', 'fire_ocrn_hour', 'fire_ocrn_min', 'daywk', 'frstt_nm',
#        'ward_nm', 'lfdau_nm', 'dsp_reqre_time', 'fire_supesn_time', 'sido_nm',
#        'sigungu_nm', 'emd_nm', 'cty_frmvl_se_nm', 'emd_se_nm', 'gis_x_axis',
#        'gis_y_axis', 'longitude', 'la', 'spt_frstt_dist',
#        'spt_safe_cnter_dist', 'spt_lfdau_dist', 'ign_htsrc_nm',
#        'ign_htsrc_sclas_nm', 'ign_fctr_lclas_nm', 'ign_fctr_sclas_nm',
#        'frst_igobj_lclas_nm', 'frst_igobj_sclas_nm', 'ign_mhrls_lclas_nm',
#        'ign_mhrls_sclas_nm', 'cmbs_expobj_lclas_nm', 'cmbs_expobj_sclas_nm',
#        'fclty_place_lclas_nm', 'fclty_place_mclas_nm', 'fclty_place_sclas_nm',
#        'vhcle_place', 'vhcle_ign_bhf', 'emrg_crg_oper_yn', 'time_unit_tmprt',
# ...

# %%
# 필요하지 않은 열 모두 삭제 후 df_new라는 새로운 데이터프레임 생성

df_new = df.drop(['wrinvstg_no','fire_type_nm','fire_ocrn_yr','qtr_se','fire_ocrn_tm','fire_ocrn_day','fire_ocrn_min','frstt_nm','ward_nm','lfdau_nm',
                  'sido_nm','cty_frmvl_se_nm','emd_se_nm','gis_x_axis','gis_y_axis','longitude','la','spt_frstt_dist','spt_safe_cnter_dist','spt_lfdau_dist',
                  'ign_htsrc_sclas_nm','ign_fctr_lclas_nm','ign_fctr_sclas_nm','ign_mhrls_lclas_nm','ign_mhrls_sclas_nm','cmbs_expobj_lclas_nm','cmbs_expobj_sclas_nm',
                  'fclty_place_lclas_nm','fclty_place_mclas_nm','emrg_crg_oper_yn','time_unit_tmprt','time_unit_rainqty','time_unit_ws','time_unit_wd','time_unit_humidity',
                  'time_unit_msnf','time_unit'], axis=1)

# %%
df_new.head()
# Out:
#    dth_cnt  injpsn_cnt  dth_hnl_dmge_cnt  prprty_dmge_amt season_se_nm  \
# 0        0           0                 0               50           겨울
# 1        0           0                 0              924           겨울
# 2        0           0                 0               66           겨울
# 3        0           0                 0            10271           겨울
# 4        0           0                 0              160           겨울
#
#    fire_ocrn_ymd  fire_ocrn_mnth  fire_ocrn_hour daywk  dsp_reqre_time  \
# 0       20230101               1              14   일요일             400
# 1       20230104               1               0   수요일             340
# 2       20230105               1              15   목요일             459
# 3       20230106               1               8   금요일             546
# 4       20230106               1              11   금요일             431
#
#    fire_supesn_time sigungu_nm emd_nm ign_htsrc_nm frst_igobj_lclas_nm  \
# ...

# %%
# car_fire_new라는 이름으로 새롭게 csv 생성

df_new.to_csv('car_fire_new.csv', index=False)
